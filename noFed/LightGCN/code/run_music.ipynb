# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="music" --topks="[20]" --recdim=6
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/music]
# 74183 interactions for training
# 18567 interactions for testing
# music Sparsity : 0.002815814891516747
# music is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 6,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="music" --topks="[20]" --recdim=64 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/music]
# 74183 interactions for training
# 18567 interactions for testing
# music Sparsity : 0.002815814891516747
# music is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /root/fedkgat/noFed/LightGCN/code/checkpoints/mf-music-64.pth.tar
# [TEST]
# {'precision': array([0.00024051]), 'recall': array([0.00048103]), 'ndcg': array([0.00047172]), 'auc': 0.49938740946587995, 'f1': 0.0011320400015734258}
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="movie" --topks="[20]" --recdim=16 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/movie]
# 7145416 interactions for training
# 1826716 interactions for testing
# movie Sparsity : 0.0055078576257062304
# movie is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 16,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /root/fedkgat/noFed/LightGCN/code/checkpoints/mf-movie-16.pth.tar
# [TEST]
# {'precision': array([0.00121874]), 'recall': array([0.00106702]), 'ndcg': array([0.00134583]), 'auc': 0.5006387623287122, 'f1': 0.002255628812473688}
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.1 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=16 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 16,
#  'lightGCN_n_layers': 3,
#  'lr': 0.1,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /root/fedkgat/noFed/LightGCN/code/checkpoints/mf-book-16.pth.tar
# [TEST]

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=1 --seed=2020 --dataset="music" --topks="[20]" --recdim=16
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/music]
# 74183 interactions for training
# 18567 interactions for testing
# music Sparsity : 0.002815814891516747
# music is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 16,
#  'lightGCN_n_layers': 1,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...
