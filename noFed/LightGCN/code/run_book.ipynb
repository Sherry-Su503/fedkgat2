# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=6
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 759018 interactions for training
# 196255 interactions for testing
# book Sparsity : 0.0002600331893281292
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 6,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=6
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 759018 interactions for training
# 196255 interactions for testing
# book Sparsity : 0.0002600331893281292
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 6,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=64
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=16
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 16,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=1 --seed=2020 --dataset="book" --topks="[20]" --recdim=64
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 1,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="book" --topks="[20]" --recdim=32 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 32,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /root/fedkgat/noFed/LightGCN/code/checkpoints/mf-book-32.pth.tar
# [TEST]
# {'precision': array([0.00035598]), 'recall': array([0.00019186]), 'ndcg': array([0.00037787]), 'auc': 0.49958380291698884, 'f1': 0.00034561669437905933}
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.1 --layer=1 --seed=2020 --dataset="book" --topks="[20]" --recdim=64
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/book]
# 611173 interactions for training
# 154499 interactions for testing
# book Sparsity : 0.0008554989634084003
# book is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 1,
#  'lr': 0.1,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...
