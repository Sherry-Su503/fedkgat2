# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="movie" --topks="[20]" --recdim=6
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/movie]
# 7145416 interactions for training
# 1826716 interactions for testing
# movie Sparsity : 0.0055078576257062304
# movie is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 6,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# generating adjacency matrix
# /root/fedkgat/noFed/LightGCN/code/dataloader.py:351: RuntimeWarning: divide by zero encountered in power
#   d_inv = np.power(rowsum, -0.5).flatten()
# costing 158.2772524356842s, saved norm_mat...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=2 --seed=2020 --dataset="movie" --topks="[20]" --recdim=32
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/movie]
# 7145416 interactions for training
# 1826716 interactions for testing
# movie Sparsity : 0.0055078576257062304
# movie is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 32,
#  'lightGCN_n_layers': 2,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded...
# ...

# %%
# !python main.py --decay=1e-4 --lr=0.01 --layer=3 --seed=2020 --dataset="movie" --topks="[20]" --recdim=6 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../../data/movie]
# 7145416 interactions for training
# 1826716 interactions for testing
# movie Sparsity : 0.0055078576257062304
# movie is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 6,
#  'lightGCN_n_layers': 3,
#  'lr': 0.01,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 64
# comment: mf
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /root/fedkgat/noFed/LightGCN/code/checkpoints/mf-movie-6.pth.tar
# [TEST]
# {'precision': array([0.00114791]), 'recall': array([0.00105486]), 'ndcg': array([0.00124748]), 'auc': 0.5009164971650586, 'f1': 0.0022561194982066058}
# ...
