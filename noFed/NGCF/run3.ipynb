# %%
# !python main.py --dataset music --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.01 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=1892, n_items=17632
# n_interactions=92834
# n_train=74241, n_test=18593, sparsity=0.00278
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='music', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.01, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [4.4s]: train==[11.64356=11.63998 + 0.00358]
# Epoch 1 [4.1s]: train==[7.09058=7.08662 + 0.00396]
# Epoch 2 [4.1s]: train==[5.70779=5.70335 + 0.00444]
# Epoch 3 [4.0s]: train==[4.55409=4.54906 + 0.00503]
# Epoch 4 [4.0s]: train==[3.66349=3.65783 + 0.00566]
# Epoch 5 [4.0s]: train==[3.13009=3.12381 + 0.00628]
# Epoch 6 [4.0s]: train==[2.74123=2.73437 + 0.00686]
# Epoch 7 [4.0s]: train==[2.30751=2.30010 + 0.00741]
# Epoch 8 [4.0s]: train==[2.07340=2.06548 + 0.00792]
# ...

# %%
# !python main.py --dataset amazon-book --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.0001 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=52643, n_items=91599
# n_interactions=2984108
# n_train=2380730, n_test=603378, sparsity=0.00062
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='./', dataset='amazon-book', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.0001, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [737.2s]: train==[620.13214=620.02783 + 0.10470]
# Traceback (most recent call last):
#   File "main.py", line 158, in <module>
#     main(args)
#   File "main.py", line 67, in main
#     ret = test(model, g, users_to_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 222, in test
#     u_g_embeddings, pos_i_g_embeddings, _ = model(
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
# ...
