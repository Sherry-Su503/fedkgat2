# %%
# !python main.py --dataset music --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.001 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=1892, n_items=17632
# n_interactions=92834
# n_train=74241, n_test=18593, sparsity=0.00278
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='music', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.001, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [4.4s]: train==[15.91701=15.91369 + 0.00332]
# Epoch 0 [4.4s + 33.6s]: train==[15.91701=15.91369 + 0.00332], recall=[0.00725, 0.01268], precision=[0.00351, 0.00305], hit=[0.05920, 0.08827], ndcg=[0.02016, 0.02817],AUC=[0.55198],F1=[0.00117]
# save the weights in path:  model/NGCF.pkl
# Epoch 1 [4.0s]: train==[9.84239=9.83906 + 0.00332]
# Epoch 1 [4.0s + 33.0s]: train==[9.84239=9.83906 + 0.00332], recall=[0.00957, 0.01778], precision=[0.00460, 0.00431], hit=[0.07294, 0.11734], ndcg=[0.02372, 0.03598],AUC=[0.55967],F1=[0.00117]
# save the weights in path:  model/NGCF.pkl
# Epoch 2 [3.9s]: train==[8.55601=8.55268 + 0.00332]
# Epoch 2 [3.9s + 31.7s]: train==[8.55601=8.55268 + 0.00332], recall=[0.01087, 0.01849], precision=[0.00531, 0.00456], hit=[0.08192, 0.12368], ndcg=[0.02827, 0.03998],AUC=[0.56784],F1=[0.00115]
# save the weights in path:  model/NGCF.pkl
# Epoch 3 [3.2s]: train==[7.92618=7.92286 + 0.00333]
# Epoch 3 [3.2s + 33.3s]: train==[7.92618=7.92286 + 0.00333], recall=[0.01054, 0.02005], precision=[0.00502, 0.00481], hit=[0.08140, 0.13055], ndcg=[0.02675, 0.04085],AUC=[0.57640],F1=[0.00116]
# Epoch 4 [4.0s]: train==[7.56729=7.56396 + 0.00333]
# Epoch 4 [4.0s + 32.5s]: train==[7.56729=7.56396 + 0.00333], recall=[0.01012, 0.01992], precision=[0.00484, 0.00481], hit=[0.08245, 0.13531], ndcg=[0.02816, 0.04280],AUC=[0.57865],F1=[0.00115]
# Epoch 5 [4.2s]: train==[7.25940=7.25606 + 0.00333]
# Epoch 5 [4.2s + 36.4s]: train==[7.25940=7.25606 + 0.00333], recall=[0.01003, 0.01913], precision=[0.00484, 0.00456], hit=[0.07822, 0.12685], ndcg=[0.02592, 0.03919],AUC=[0.58134],F1=[0.00114]
# Epoch 6 [4.3s]: train==[6.98854=6.98521 + 0.00334]
# Epoch 6 [4.3s + 35.5s]: train==[6.98854=6.98521 + 0.00334], recall=[0.01100, 0.02180], precision=[0.00536, 0.00514], hit=[0.08774, 0.14323], ndcg=[0.03186, 0.04711],AUC=[0.58600],F1=[0.00114]
# save the weights in path:  model/NGCF.pkl
# Epoch 7 [4.0s]: train==[6.81742=6.81407 + 0.00334]
# Epoch 7 [4.0s + 34.5s]: train==[6.81742=6.81407 + 0.00334], recall=[0.01014, 0.01877], precision=[0.00476, 0.00452], hit=[0.07611, 0.12156], ndcg=[0.02498, 0.03784],AUC=[0.58487],F1=[0.00111]
# Epoch 8 [4.0s]: train==[6.68339=6.68004 + 0.00335]
# Epoch 8 [4.0s + 30.0s]: train==[6.68339=6.68004 + 0.00335], recall=[0.01322, 0.02150], precision=[0.00634, 0.00523], hit=[0.09619, 0.13002], ndcg=[0.03294, 0.04450],AUC=[0.58736],F1=[0.00111]
# save the weights in path:  model/NGCF.pkl
# Epoch 9 [4.4s + 31.5s]: train==[6.61236=6.60901 + 0.00335], recall=[0.01150, 0.02155], precision=[0.00560, 0.00522], hit=[0.08615, 0.13319], ndcg=[0.02916, 0.04321],AUC=[0.58576],F1=[0.00110]
# Epoch 10 [3.7s]: train==[6.57359=6.57024 + 0.00335]
# Epoch 10 [3.7s + 32.2s]: train==[6.57359=6.57024 + 0.00335], recall=[0.01186, 0.02146], precision=[0.00547, 0.00513], hit=[0.08087, 0.13266], ndcg=[0.02586, 0.04036],AUC=[0.58646],F1=[0.00109]
# Epoch 11 [3.9s]: train==[6.44954=6.44618 + 0.00336]
# Epoch 11 [3.9s + 30.2s]: train==[6.44954=6.44618 + 0.00336], recall=[0.01026, 0.01999], precision=[0.00505, 0.00489], hit=[0.08192, 0.13319], ndcg=[0.02927, 0.04355],AUC=[0.58661],F1=[0.00111]
# Epoch 12 [4.1s]: train==[6.39658=6.39321 + 0.00337]
# Epoch 12 [4.1s + 33.0s]: train==[6.39658=6.39321 + 0.00337], recall=[0.00994, 0.01813], precision=[0.00478, 0.00440], hit=[0.07875, 0.11839], ndcg=[0.02617, 0.03803],AUC=[0.58889],F1=[0.00112]
# Epoch 13 [4.3s]: train==[6.35737=6.35400 + 0.00337]
# Epoch 13 [4.3s + 34.8s]: train==[6.35737=6.35400 + 0.00337], recall=[0.01039, 0.01842], precision=[0.00505, 0.00449], hit=[0.07981, 0.11734], ndcg=[0.03104, 0.04238],AUC=[0.58805],F1=[0.00112]
# Early stopping is trigger at step: 5 log:0.010387093526628388
# Traceback (most recent call last):
#   File "main.py", line 158, in <module>
#     main(args)
#   File "main.py", line 132, in main
#     best_auc_0 = max(aucs[:, 0])
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# !python main.py --dataset music --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.001 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=1892, n_items=17632
# n_interactions=92834
# n_train=74241, n_test=18593, sparsity=0.00278
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='music', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.001, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [4.0s]: train==[16.08530=16.08198 + 0.00332]
# Epoch 0 [4.0s + 30.7s]: train==[16.08530=16.08198 + 0.00332], recall=[0.00513, 0.00991], precision=[0.00256, 0.00244], hit=[0.04545, 0.08245], ndcg=[0.01535, 0.02377],AUC=[0.55175],F1=[0.00186]
# save the weights in path:  model/NGCF.pkl
# Epoch 1 [4.0s]: train==[10.09532=10.09200 + 0.00332]
# Epoch 1 [4.0s + 28.2s]: train==[10.09532=10.09200 + 0.00332], recall=[0.00747, 0.01572], precision=[0.00367, 0.00378], hit=[0.06448, 0.11047], ndcg=[0.02053, 0.03286],AUC=[0.55880],F1=[0.00217]
# save the weights in path:  model/NGCF.pkl
# Epoch 2 [3.8s]: train==[8.66102=8.65769 + 0.00332]
# Epoch 2 [3.8s + 34.2s]: train==[8.66102=8.65769 + 0.00332], recall=[0.01038, 0.01877], precision=[0.00510, 0.00459], hit=[0.08034, 0.12421], ndcg=[0.02672, 0.03901],AUC=[0.56635],F1=[0.00244]
# save the weights in path:  model/NGCF.pkl
# Epoch 3 [4.0s]: train==[7.87246=7.86913 + 0.00333]
# Epoch 3 [4.0s + 34.2s]: train==[7.87246=7.86913 + 0.00333], recall=[0.00994, 0.01933], precision=[0.00481, 0.00472], hit=[0.07611, 0.13002], ndcg=[0.02412, 0.03883],AUC=[0.57133],F1=[0.00264]
# Epoch 4 [4.1s]: train==[7.46770=7.46437 + 0.00333]
# Epoch 4 [4.1s + 34.4s]: train==[7.46770=7.46437 + 0.00333], recall=[0.01026, 0.02098], precision=[0.00494, 0.00509], hit=[0.07981, 0.13636], ndcg=[0.02542, 0.04109],AUC=[0.57914],F1=[0.00284]
# Epoch 5 [4.3s]: train==[7.28821=7.28487 + 0.00333]
# Epoch 5 [4.3s + 32.4s]: train==[7.28821=7.28487 + 0.00333], recall=[0.01272, 0.02304], precision=[0.00624, 0.00555], hit=[0.09884, 0.14006], ndcg=[0.03007, 0.04324],AUC=[0.58053],F1=[0.00294]
# save the weights in path:  model/NGCF.pkl
# Epoch 6 [3.9s]: train==[7.09430=7.09097 + 0.00334]
# Epoch 6 [3.9s + 32.6s]: train==[7.09430=7.09097 + 0.00334], recall=[0.01128, 0.02082], precision=[0.00544, 0.00503], hit=[0.08879, 0.13161], ndcg=[0.03158, 0.04487],AUC=[0.57941],F1=[0.00298]
# Epoch 7 [4.0s]: train==[6.87958=6.87624 + 0.00334]
# Epoch 7 [4.0s + 30.7s]: train==[6.87958=6.87624 + 0.00334], recall=[0.01207, 0.02090], precision=[0.00595, 0.00511], hit=[0.09355, 0.13214], ndcg=[0.03215, 0.04474],AUC=[0.58258],F1=[0.00305]
# Epoch 8 [3.9s]: train==[6.68163=6.67828 + 0.00335]
# Epoch 8 [3.9s + 31.1s]: train==[6.68163=6.67828 + 0.00335], recall=[0.01036, 0.01953], precision=[0.00505, 0.00468], hit=[0.08087, 0.13108], ndcg=[0.02746, 0.04061],AUC=[0.58324],F1=[0.00310]
# Epoch 9 [4.5s + 33.8s]: train==[6.53903=6.53568 + 0.00335], recall=[0.01270, 0.02190], precision=[0.00613, 0.00533], hit=[0.09672, 0.13636], ndcg=[0.03540, 0.04809],AUC=[0.58727],F1=[0.00316]
# Epoch 10 [3.5s]: train==[6.49840=6.49505 + 0.00336]
# Epoch 10 [3.5s + 33.6s]: train==[6.49840=6.49505 + 0.00336], recall=[0.01279, 0.02255], precision=[0.00613, 0.00538], hit=[0.08985, 0.13319], ndcg=[0.03139, 0.04464],AUC=[0.58457],F1=[0.00318]
# save the weights in path:  model/NGCF.pkl
# Epoch 11 [4.0s]: train==[6.44987=6.44651 + 0.00336]
# Epoch 11 [4.0s + 33.8s]: train==[6.44987=6.44651 + 0.00336], recall=[0.01320, 0.02261], precision=[0.00610, 0.00536], hit=[0.08721, 0.13372], ndcg=[0.03109, 0.04468],AUC=[0.58803],F1=[0.00327]
# save the weights in path:  model/NGCF.pkl
# Epoch 12 [3.6s]: train==[6.33607=6.33270 + 0.00337]
# ^C
# Process ForkPoolWorker-1645:
# Process ForkPoolWorker-1589:
# Process ForkPoolWorker-1593:
# Process ForkPoolWorker-1615:
# Process ForkPoolWorker-1649:
# Process ForkPoolWorker-1663:
# Process ForkPoolWorker-1660:
# Process ForkPoolWorker-1643:
# Process ForkPoolWorker-1577:
# Process ForkPoolWorker-1621:
# Process ForkPoolWorker-1648:
# Process ForkPoolWorker-1664:
# Process ForkPoolWorker-1601:
# Process ForkPoolWorker-1608:
# Process ForkPoolWorker-1620:
# Process ForkPoolWorker-1659:
# Process ForkPoolWorker-1654:
# Process ForkPoolWorker-1583:
# Process ForkPoolWorker-1613:
# Process ForkPoolWorker-1590:
# Process ForkPoolWorker-1647:
# Process ForkPoolWorker-1604:
# Process ForkPoolWorker-1605:
# Process ForkPoolWorker-1661:
# Process ForkPoolWorker-1653:
# Process ForkPoolWorker-1658:
# Process ForkPoolWorker-1598:
# Process ForkPoolWorker-1639:
# Process ForkPoolWorker-1632:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-1584:
# Process ForkPoolWorker-1624:
# Process ForkPoolWorker-1592:
# Traceback (most recent call last):
# Process ForkPoolWorker-1646:
# Process ForkPoolWorker-1625:
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1635:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-1626:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-1595:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Process ForkPoolWorker-1631:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Process ForkPoolWorker-1662:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 31, in ranklist_by_heapq
#     item_score[i] = rating[i]
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-1627:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 146, in test_one_user
#     all_items = set(range(ITEM_NUM))
# Process ForkPoolWorker-1562:
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-1588:
# KeyboardInterrupt
# Process ForkPoolWorker-1556:
# Process ForkPoolWorker-1544:
# Process ForkPoolWorker-1616:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-1559:
# Process ForkPoolWorker-1581:
# Process ForkPoolWorker-1549:
# Process ForkPoolWorker-1651:
# Process ForkPoolWorker-1628:
# Process ForkPoolWorker-1560:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1641:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1541:
# Process ForkPoolWorker-1545:
# Process ForkPoolWorker-1554:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-1552:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-1580:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-1575:
# Process ForkPoolWorker-1599:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
# Process ForkPoolWorker-1623:
# Process ForkPoolWorker-1558:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# Process ForkPoolWorker-1553:
# Process ForkPoolWorker-1563:
# Process ForkPoolWorker-1565:
# Process ForkPoolWorker-1638:
# Process ForkPoolWorker-1609:
# Process ForkPoolWorker-1582:
# Process ForkPoolWorker-1629:
# Process ForkPoolWorker-1656:
# Process ForkPoolWorker-1655:
# Process ForkPoolWorker-1551:
# Process ForkPoolWorker-1622:
# Process ForkPoolWorker-1570:
# Process ForkPoolWorker-1561:
# Traceback (most recent call last):
# Process ForkPoolWorker-1550:
# Process ForkPoolWorker-1568:
# Process ForkPoolWorker-1542:
# Process ForkPoolWorker-1547:
# Process ForkPoolWorker-1576:
# Process ForkPoolWorker-1633:
# Process ForkPoolWorker-1571:
# Process ForkPoolWorker-1548:
# Process ForkPoolWorker-1637:
# Process ForkPoolWorker-1600:
# Process ForkPoolWorker-1657:
# Process ForkPoolWorker-1630:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1650:
# Process ForkPoolWorker-1603:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-1537:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Traceback (most recent call last):
# Process ForkPoolWorker-1611:
# Process ForkPoolWorker-1636:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
# Process ForkPoolWorker-1642:
# Process ForkPoolWorker-1539:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
# Process ForkPoolWorker-1602:
# Process ForkPoolWorker-1572:
# Traceback (most recent call last):
# Process ForkPoolWorker-1614:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# Process ForkPoolWorker-1594:
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-1585:
# Process ForkPoolWorker-1619:
# Process ForkPoolWorker-1586:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-1610:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-1578:
# Process ForkPoolWorker-1540:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-1591:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-1587:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Process ForkPoolWorker-1606:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
# Process ForkPoolWorker-1597:
# Process ForkPoolWorker-1538:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-1567:
# KeyboardInterrupt
# Process ForkPoolWorker-1618:
# Process ForkPoolWorker-1579:
# Process ForkPoolWorker-1543:
# Process ForkPoolWorker-1607:
# Process ForkPoolWorker-1564:
# Traceback (most recent call last):
# Process ForkPoolWorker-1644:
# Process ForkPoolWorker-1596:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
# Process ForkPoolWorker-1617:
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# Process ForkPoolWorker-1573:
# KeyboardInterrupt
# Process ForkPoolWorker-1652:
# Traceback (most recent call last):
# Process ForkPoolWorker-1546:
# Traceback (most recent call last):
# Process ForkPoolWorker-1557:
# Process ForkPoolWorker-1555:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 144, in test_one_user
#     user_pos_test = data_generator.test_set[u]
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-1640:
# Process ForkPoolWorker-1566:
# Traceback (most recent call last):
# Process ForkPoolWorker-1612:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Process ForkPoolWorker-1634:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Traceback (most recent call last):
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
# Process ForkPoolWorker-1569:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 78, in get_auc
#     breakpoint()
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 204, in wrapper
#     validate_parameter_constraints(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 76, in validate_parameter_constraints
#     if constraint.is_satisfied_by(param_val):
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 363, in is_satisfied_by
#     return isinstance(val, self.type) and val in self.options
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 73, in get_auc
#     auc = roc_auc_score(y_true, y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 627, in roc_auc_score
#     return _average_binary_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 75, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 387, in _binary_roc_auc_score
#     fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 1095, in roc_curve
#     fps, tps, thresholds = _binary_clf_curve(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 827, in _binary_clf_curve
#     desc_score_indices = np.argsort(y_score, kind="mergesort")[::-1]
#   File "<__array_function__ internals>", line 200, in argsort
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 1146, in argsort
#     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 78, in get_auc
#     breakpoint()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1239, in f1_score
#     return fbeta_score(
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1413, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1728, in precision_recall_fscore_support
#     MCM = multilabel_confusion_matrix(
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 73, in get_auc
#     auc = roc_auc_score(y_true, y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 505, in multilabel_confusion_matrix
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 108, in _check_targets
#     y_pred = column_or_1d(y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 627, in roc_auc_score
#     return _average_binary_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 1219, in column_or_1d
#     y = check_array(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 70, in _average_binary_score
#     y_type = type_of_target(y_true)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 311, in type_of_target
#     if is_multilabel(y):
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 167, in is_multilabel
#     y = check_array(y, dtype=None, **check_y_kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 375, in _asarray_with_order
#     if _is_numpy_namespace(xp):
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 72, in _is_numpy_namespace
#     return xp.__name__ in {"numpy", "array_api_compat.numpy", "numpy.array_api"}
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 227, in __getattr__
#     def __getattr__(self, name):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
# Traceback (most recent call last):
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 73, in get_auc
#     auc = roc_auc_score(y_true, y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 627, in roc_auc_score
#     return _average_binary_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 70, in _average_binary_score
#     y_type = type_of_target(y_true)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 388, in type_of_target
#     if xp.unique_values(y).shape[0] > 2 or (y.ndim == 2 and len(first_row) > 1):
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 262, in unique_values
#     return numpy.unique(x)
#   File "<__array_function__ internals>", line 200, in unique
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 274, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 336, in _unique1d
#     ar.sort()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 78, in get_auc
#     breakpoint()
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1239, in f1_score
#     return fbeta_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1413, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1728, in precision_recall_fscore_support
#     MCM = multilabel_confusion_matrix(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 505, in multilabel_confusion_matrix
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 85, in _check_targets
#     type_true = type_of_target(y_true, input_name="y_true")
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 331, in type_of_target
#     y = check_array(y, dtype=None, **check_y_kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 34, in ranklist_by_heapq
#     K_max_item_score = heapq.nlargest(K_max, item_score, key=item_score.get)
#   File "/root/miniconda3/lib/python3.8/heapq.py", line 570, in nlargest
#     for elem in it:
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
# Traceback (most recent call last):
# Traceback (most recent call last):
# ...
#     type_true = type_of_target(y_true, input_name="y_true")
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 331, in type_of_target
#     y = check_array(y, dtype=None, **check_y_kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 1219, in column_or_1d
#     y = check_array(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1724, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1501, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1504, in _check_set_wise_labels
#     present_labels = unique_labels(y_true, y_pred).tolist()
# KeyboardInterrupt
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 78, in get_auc
#     breakpoint()
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 86, in _check_targets
#     type_pred = type_of_target(y_pred, input_name="y_pred")
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 112, in unique_labels
#     ys_labels = set(chain.from_iterable((i for i in _unique_labels(y)) for y in ys))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 311, in type_of_target
#     if is_multilabel(y):
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 167, in is_multilabel
#     y = check_array(y, dtype=None, **check_y_kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 112, in <genexpr>
#     ys_labels = set(chain.from_iterable((i for i in _unique_labels(y)) for y in ys))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1239, in f1_score
#     return fbeta_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 24, in _unique_multiclass
#     return xp.unique_values(xp.asarray(y))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 262, in unique_values
#     return numpy.unique(x)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1413, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 78, in get_auc
#     breakpoint()
#   File "<__array_function__ internals>", line 200, in unique
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
# KeyboardInterrupt
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in get_auc
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 274, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1788, in precision_recall_fscore_support
#     recall = _nanaverage(recall, weights=weights)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 77, in <listcomp>
#     print('y_score',y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1239, in f1_score
#     return fbeta_score(
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 336, in _unique1d
#     ar.sort()
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py", line 1191, in _nanaverage
#     return np.nanmean(a)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 200, in nanmean
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1413, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 1048, in nanmean
#     avg = _divide_by_count(tot, cnt, out=out)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py", line 222, in _divide_by_count
#     return a.dtype.type(a / b)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1728, in precision_recall_fscore_support
#     MCM = multilabel_confusion_matrix(
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/_ufunc_config.py", line 436, in __exit__
#     seterr(**self.oldstate)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/_ufunc_config.py", line 110, in seterr
#     pyvals = umath.geterrobj()
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 505, in multilabel_confusion_matrix
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 107, in _check_targets
#     y_true = column_or_1d(y_true)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 1219, in column_or_1d
#     y = check_array(
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1413, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1724, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 1095, in roc_curve
#     fps, tps, thresholds = _binary_clf_curve(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 1501, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 24, in _unique_multiclass
#     return xp.unique_values(xp.asarray(y))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 827, in _binary_clf_curve
#     desc_score_indices = np.argsort(y_score, kind="mergesort")[::-1]
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 379, in type_of_target
#     if xp.isdtype(y.dtype, "real floating"):
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 1095, in roc_curve
#     fps, tps, thresholds = _binary_clf_curve(
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py", line 86, in _check_targets
#     type_pred = type_of_target(y_pred, input_name="y_pred")
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 262, in unique_values
#     return numpy.unique(x)
#   File "<__array_function__ internals>", line 200, in argsort
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 827, in _binary_clf_curve
#     desc_score_indices = np.argsort(y_score, kind="mergesort")[::-1]
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 331, in type_of_target
#     y = check_array(y, dtype=None, **check_y_kwargs)
#   File "<__array_function__ internals>", line 200, in unique
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 1146, in argsort
#     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in ranklist_by_heapq
#     auc,f1 = get_auc(item_score, user_pos_test)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 283, in isdtype
#     return isdtype(dtype, kind, xp=self)
#   File "<__array_function__ internals>", line 200, in argsort
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 274, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 73, in get_auc
#     auc = roc_auc_score(y_true, y_score)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 84, in isdtype
#     return _isdtype_single(dtype, kind, xp=xp)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 1146, in argsort
#     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 340, in _unique1d
#     if (equal_nan and aux.shape[0] > 0 and aux.dtype.kind in "cfmM" and
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_param_validation.py", line 214, in wrapper
#     return func(*args, **kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 101, in _isdtype_single
#     return dtype in {xp.float32, xp.float64}
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 604, in roc_auc_score
#     y_type = type_of_target(y_true, input_name="y_true")
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 227, in __getattr__
#     def __getattr__(self, name):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 331, in type_of_target
#     y = check_array(y, dtype=None, **check_y_kwargs)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# KeyboardInterrupt
#   File "/root/miniconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 149, in test_one_user
#   File "/root/fedkgat/noFed/NGCF/utility/batch_test.py", line 42, in r

# %%
# !python main.py --dataset music --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.001 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=1892, n_items=17632
# n_interactions=92834
# n_train=74241, n_test=18593, sparsity=0.00278
