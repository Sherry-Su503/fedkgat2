# %%
# !python main.py --dataset book --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.01 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# ^C
# Traceback (most recent call last):
#   File "main.py", line 4, in <module>
#     import torch
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/__init__.py", line 1504, in <module>
#     from . import masked
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/masked/__init__.py", line 3, in <module>
#     from ._ops import (
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/masked/_ops.py", line 11, in <module>
#     from torch._prims_common import corresponding_real_dtype
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/_prims_common/__init__.py", line 23, in <module>
#     import sympy
#   File "/root/miniconda3/lib/python3.8/site-packages/sympy/__init__.py", line 22, in <module>
#     import mpmath
#   File "/root/miniconda3/lib/python3.8/site-packages/mpmath/__init__.py", line 5, in <module>
#     from .ctx_fp import FPContext
#   File "/root/miniconda3/lib/python3.8/site-packages/mpmath/ctx_fp.py", line 1, in <module>
# ...

# %%
# !python main.py --dataset book --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.1 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=12053, n_items=304792
# n_interactions=955273
# n_train=759018, n_test=196255, sparsity=0.00026
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='book', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.1, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [130.9s]: train==[1232.01099=1230.63013 + 1.38047]
# Epoch 1 [130.7s]: train==[2560.05591=2555.75610 + 4.30043]
# Epoch 2 [130.7s]: train==[2849.47266=2842.66602 + 6.80692]
# Epoch 3 [130.7s]: train==[2904.78345=2895.87646 + 8.90603]
# Epoch 4 [130.7s]: train==[2885.07593=2874.33618 + 10.74181]
# Epoch 5 [130.7s]: train==[2864.30151=2851.91309 + 12.38803]
# Epoch 6 [130.7s]: train==[2884.83813=2870.90381 + 13.93296]
# Epoch 7 [130.8s]: train==[2816.57300=2801.19580 + 15.37722]
# Epoch 8 [130.7s]: train==[2779.08032=2762.33838 + 16.74301]
# ...

# %%
# !python main.py --dataset book --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.1 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=3371, n_items=265500
# n_interactions=765672
# n_train=611173, n_test=154499, sparsity=0.00086
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='book', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.1, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [240.6s]: train==[808.99036=808.08667 + 0.90374]
# Epoch 0 [241.0s + 418.6s]: train==[808.99036=808.08667 + 0.90374], recall=[0.00021, 0.00053], precision=[0.00042, 0.00044], hit=[0.00801, 0.01750], ndcg=[0.00277, 0.00471],AUC=[0.51256],F1=[0.00032]
# Epoch 1 [242.7s]: train==[1920.41443=1917.64331 + 2.77053]
# Epoch 1 [243.0s + 430.2s]: train==[1920.41443=1917.64331 + 2.77053], recall=[0.00040, 0.00069], precision=[0.00056, 0.00052], hit=[0.01127, 0.02047], ndcg=[0.00399, 0.00588],AUC=[0.52245],F1=[0.00036]
# ^C

# %%
# !python main.py --dataset book --regs [1e-5] --embed_size 64 --layer_size [64] --lr 0.01 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1] --gpu 0
# Out:
# n_users=3371, n_items=265500
# n_interactions=765672
# n_train=611173, n_test=154499, sparsity=0.00086
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='book', embed_size=64, epoch=400, gpu=0, layer_size=[64], lr=0.01, mess_dropout=[0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [93.7s]: train==[123.24980=123.21296 + 0.03681]
# Epoch 1 [74.7s]: train==[45.84888=45.76741 + 0.08149]
# Epoch 2 [61.0s]: train==[31.86658=31.75775 + 0.10882]
# Epoch 3 [76.3s]: train==[26.40605=26.27538 + 0.13068]
# Epoch 4 [105.6s]: train==[23.79875=23.64888 + 0.14986]
# Epoch 5 [106.3s]: train==[21.35058=21.18310 + 0.16748]
# Epoch 6 [106.1s]: train==[19.94366=19.75976 + 0.18389]
# Epoch 7 [95.7s]: train==[19.23686=19.03794 + 0.19893]
# Epoch 8 [93.2s]: train==[18.48345=18.27002 + 0.21342]
# ...

# %%
# !python main.py --dataset book --regs [1e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.1 --save_flag 1 --batch_size 1024 --epoch 400 --verbose 1 --mess_dropout [0.1,0.1,0.1] --gpu 0
# Out:
# n_users=3371, n_items=265500
# n_interactions=765672
# n_train=611173, n_test=154499, sparsity=0.00086
# Namespace(Ks='[20, 40]', batch_size=1024, data_path='../data/', dataset='book', embed_size=64, epoch=400, gpu=0, layer_size=[64, 64, 64], lr=0.1, mess_dropout=[0.1, 0.1, 0.1], model_name='NGCF.pkl', regs=[1e-05], report=0, save_flag=1, test_flag='part', verbose=1, weights_path='model/')
# Epoch 0 [148.6s]: train==[797.55157=796.65033 + 0.90143]
# Epoch 1 [96.3s]: train==[1883.71863=1880.94763 + 2.77055]
# Epoch 2 [91.8s]: train==[2267.42358=2262.97607 + 4.44854]
# Epoch 3 [96.6s]: train==[2379.61816=2373.73096 + 5.88580]
# Epoch 4 [104.2s]: train==[2330.96655=2323.80981 + 7.15822]
# Epoch 5 [96.2s]: train==[2262.88965=2254.57739 + 8.31195]
# Epoch 6 [91.7s]: train==[2218.76587=2209.36670 + 9.40095]
# Epoch 7 [128.4s]: train==[2154.24756=2143.82031 + 10.42839]
# Epoch 8 [175.8s]: train==[2165.98218=2154.57007 + 11.41079]
# ...
